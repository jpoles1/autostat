# %%
from langchain_openai import ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from typing import List
import pandas as pd
import numpy as np
import json

# %%
llm = ChatOpenAI(base_url="http://THOTH.local:1234/v1/", api_key="na", temperature=0.5)

# %%
class DatasetCol(BaseModel):
    name: str = Field(description="The name of the column.")
    type: str = Field(description="The type of the column. One of 'int', 'float', 'str', 'bool'.")
    description: str = Field(description="A description of the column.")
    dependent: bool = Field(description="Whether this column is dependent on other columns.")
    function: str = Field(description="A python function that generates the data for this column. The function takes parameters and returns the value for the column in that row. The function takes the row as a paramter with each column accessbile by name (Eg: row[\"name\"]). Independent variables cannot use any other variables in the dataset in their function including themselves.")

class DatasetGen(BaseModel):
    columns: List[DatasetCol] = Field(description="The columns of the dataset.")

# Set up a parser + inject instructions into the prompt template.
parser = JsonOutputParser(pydantic_object=DatasetGen)

# %%
def parser_to_prompt_schema(parser):
    schema = {k: v for k, v in parser._get_schema(parser.pydantic_object).items()}

    # Remove extraneous fields.
    reduced_schema = schema
    if "title" in reduced_schema:
        del reduced_schema["title"]
    if "type" in reduced_schema:
        del reduced_schema["type"]
    # Ensure json in context is well-formed with double quotes.
    schema_str = json.dumps(reduced_schema)

    return schema_str

# %%
def try_eval(fn_str, *params):
    try:
        return eval(fn_str)(*params)
    except:
        return None
def create_dataframe(data_template, n):
    columns = data_template['columns']
    data = {}
    independent_vars = {}
    # Generate values for independent variables
    for column in columns:
        if not column['dependent']:
            col_name = column['name']
            col_type = column['type']
            col_function = column['function']
            values = [try_eval(col_function, i) for i in range(n)]
            data[col_name] = values
    # Calculate values for dependent variables
    for column in columns:
        if column['dependent']:
            col_name = column['name']
            col_type = column['type']
            col_function = column['function']
            values = [eval(col_function)(pd.DataFrame(data).to_dict('records')[i]) for i in range(n)]
            data[col_name] = values

    df = pd.DataFrame(data)
    return df

# %%
template = '''
You are a helpful assistant that answers in JSON.
Generate an artificial medical research dataset containing 20-30 columns each.
The subject of this dataset is: {subject}.
For each column provide a python function using numpy to generate the data.

Here's the json schema you must adhere to:
<schema>
{schema}
</schema>
'''
prompt = PromptTemplate(
    template=template,
    input_variables=["subject"],
    partial_variables={"schema": parser_to_prompt_schema(parser)},
)

# %%
chain = prompt | llm | parser
data_template = chain.invoke({"subject": "blindness in diabetes"})

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
display(pd.DataFrame(data_template["columns"]))
# Out:
#                        name   type  \
# 0                patient_id    str
# 1                       age    int
# 2                    gender    str
# 3         diabetes_duration    int
# 4            blood_pressure  float
# 5     fasting_blood_glucose  float
# 6           body_mass_index  float
# 7                    smoker   bool
# 8                 blindness   bool
# 9               retinopathy   bool
# 10               neuropathy   bool
# 11              nephropathy   bool
# 12            foot_problems   bool
# 13             hypertension   bool
# 14           hyperlipidemia   bool
# 15                  obesity   bool
# 16  family_history_diabetes   bool
# 17        physical_activity   bool
# 18             diet_control   bool
# 19     medication_adherence   bool
# 20         health_insurance   bool
#
#                                                       description  dependent  \
# 0                             Unique identifier for each patient.      False
# 1                                    Age of the patient in years.      False
# 2                         Gender of the patient (Male or Female).      False
# 3                                  Duration of diabetes in years.      False
# 4                           Blood pressure of the patient (mmHg).      False
# 5                            Fasting blood glucose level (mg/dL).      False
# 6                        Body mass index of the patient (kg/m^2).      False
# 7                         Whether the patient is a smoker or not.      False
# 8       Whether the patient has blindness due to diabetes or not.       True
# 9     Whether the patient has retinopathy due to diabetes or not.       True
# 10     Whether the patient has neuropathy due to diabetes or not.       True
# 11    Whether the patient has nephropathy due to diabetes or not.       True
# 12  Whether the patient has foot problems due to diabetes or not.       True
# 13                   Whether the patient has hypertension or not.      False
# 14                 Whether the patient has hyperlipidemia or not.      False
# 15                           Whether the patient is obese or not.      False
# 16   Whether the patient has a family history of diabetes or not.      False
# 17               Whether the patient is physically active or not.      False
# 18              Whether the patient has good diet control or not.      False
# 19              Whether the patient adheres to medication or not.      False
# 20               Whether the patient has health insurance or not.      False
#
#                                                                                   function
# 0                                                       lambda row: str(row['patient_id'])
# 1                                                   lambda row: np.random.randint(18, 100)
# 2                               lambda row: 'Male' if np.random.rand() > 0.5 else 'Female'
# 3                                                     lambda row: np.random.randint(1, 20)
# 4                                      lambda row: np.random.uniform(low=80.0, high=140.0)
# 5                                      lambda row: np.random.uniform(low=70.0, high=120.0)
# 6                                       lambda row: np.random.uniform(low=18.5, high=30.0)
# 7                                                   lambda row: bool(np.random.randint(2))
# 8   lambda row: (row['fasting_blood_glucose'] > 126.0) and (row['blood_pressure'] > 135.0)
# 9   lambda row: (row['fasting_blood_glucose'] > 126.0) and (row['blood_pressure'] > 135.0)
# 10  lambda row: (row['fasting_blood_glucose'] > 126.0) and (row['blood_pressure'] > 135.0)
# 11  lambda row: (row['fasting_blood_glucose'] > 126.0) and (row['blood_pressure'] > 135.0)
# 12  lambda row: (row['fasting_blood_glucose'] > 126.0) and (row['blood_pressure'] > 135.0)
# 13                                                  lambda row: bool(np.random.randint(2))
# 14                                                  lambda row: bool(np.random.randint(2))
# 15                                                  lambda row: bool(np.random.randint(2))
# 16                                                  lambda row: bool(np.random.randint(2))
# 17                                                  lambda row: bool(np.random.randint(2))
# 18                                                  lambda row: bool(np.random.randint(2))
# 19                                                  lambda row: bool(np.random.randint(2))
# 20                                                  lambda row: bool(np.random.randint(2))

# %%
create_dataframe(data_template, 100)
# Out:
#    patient_id  age  gender  diabetes_duration  blood_pressure  \
# 0        None   47    Male                  7       89.016368
# 1        None   85    Male                  7      105.487086
# 2        None   84  Female                 11      119.003098
# 3        None   68    Male                  1      125.072254
# 4        None   31  Female                  5       88.188785
# 5        None   87  Female                  9      135.371076
# 6        None   88    Male                 11       85.849524
# 7        None   35  Female                  3      126.680059
# 8        None   68    Male                 18      100.672366
# 9        None   68  Female                 12       81.336260
# 10       None   87    Male                  5      139.812135
# 11       None   47  Female                 15      110.809445
# 12       None   76    Male                  4       80.645210
# 13       None   62  Female                 16      104.539433
# 14       None   18    Male                 14      103.472299
# 15       None   82  Female                 12      100.412752
# 16       None   25    Male                 10       88.726348
# 17       None   34  Female                  5      119.083879
# 18       None   78  Female                 18      102.383176
# 19       None   73    Male                 14      105.409759
# 20       None   65    Male                 13       91.894223
# 21       None   87    Male                 11      128.463863
# 22       None   74  Female                 19       83.595008
# 23       None   38    Male                 13      116.181631
# 24       None   82    Male                 15      111.451074
# 25       None   71  Female                 12      100.502611
# 26       None   47    Male                 14      101.063167
# 27       None   82  Female                  2       85.359717
# 28       None   77  Female                  8      102.540627
# 29       None   71    Male                  3      107.933644
# 30       None   22  Female                 15      127.563167
# 31       None   92    Male                 14      100.045366
# 32       None   72    Male                 13       89.212371
# 33       None   30    Male                 15       93.366789
# 34       None   75  Female                 14      137.277681
# 35       None   80  Female                  3      128.723332
# 36       None   75  Female                 17      116.306564
# 37       None   52    Male                 18      130.010629
# 38       None   71  Female                  3      112.113448
# 39       None   48  Female                 12       83.014006
# 40       None   58  Female                 14       88.037074
# 41       None   53    Male                  5      101.369777
# 42       None   78  Female                 17       86.317099
# 43       None   61  Female                 12       98.171498
# 44       None   82    Male                 17      122.603284
# 45       None   42    Male                 18      132.306538
# 46       None   78  Female                  2       96.683516
# 47       None   38    Male                 19       98.074307
# 48       None   91    Male                  9       80.109792
# 49       None   81  Female                  2      129.911260
# 50       None   70    Male                  1      113.571507
# 51       None   70  Female                  8      129.341993
# 52       None   55    Male                 12      115.021574
# 53       None   71    Male                  5      127.586485
# 54       None   23    Male                  2      117.769978
# 55       None   77  Female                 14       97.149236
# 56       None   53    Male                  4      120.737467
# 57       None   44  Female                  3       91.045230
# 58       None   49    Male                 13      121.229905
# 59       None   32  Female                 13      108.745990
# 60       None   26  Female                 11      122.067503
# 61       None   35  Female                  6      138.052336
# 62       None   62  Female                  8      109.266804
# 63       None   21  Female                 19      116.697688
# 64       None   95    Male                  3      133.714012
# 65       None   33  Female                  5      106.970807
# 66       None   19  Female                 14       95.001454
# 67       None   56    Male                 18      121.175228
# 68       None   78    Male                  7       96.320382
# 69       None   69    Male                 11      111.419515
# 70       None   28    Male                 14      117.559034
# 71       None   41    Male                  7      106.035853
# 72       None   81    Male                  3       85.363463
# 73       None   27  Female                  8      114.767794
# 74       None   66  Female                 16      127.366744
# 75       None   25    Male                  4      103.063272
# 76       None   64  Female                 17      102.108660
# 77       None   71  Female                 13       97.468452
# 78       None   33  Female                 11       81.730478
# 79       None   65  Female                 11      132.521912
# 80       None   45    Male                 17       92.369728
# 81       None   57    Male                 12       95.996835
# 82       None   26    Male                 14      127.018014
# 83       None   18    Male                  8      137.154909
# 84       None   60    Male                 14      135.754356
# 85       None   78  Female                  5      102.121757
# 86       None   66    Male                 10      120.853805
# 87       None   58    Male                 18      128.233086
# 88       None   96  Female                 12      116.935394
# 89       None   80    Male                 14       81.174999
# 90       None   56    Male                 19       85.920131
# 91       None   30  Female                  6      109.652635
# 92       None   26    Male                 12      130.821098
# 93       None   92  Female                  6      134.751541
# 94       None   54    Male                 19      111.963125
# 95       None   86  Female                 14      117.607785
# 96       None   86  Female                  1      118.115177
# 97       None   20    Male                 19      134.882267
# 98       None   96  Female                  9      131.449265
# 99       None   31    Male                  4       88.116538
#
#     fasting_blood_glucose  body_mass_index  smoker  hypertension  \
# 0              104.443600        28.403275   False         False
# 1               73.908716        22.080301    True          True
# 2              107.711623        19.373628   False         False
# 3               96.350197        20.190769    True         False
# 4              111.851569        27.448994    True          True
# 5               84.067005        24.513361   False          True
# 6               75.605231        24.413076   False         False
# 7               90.648062        26.430279    True          True
# 8              113.065373        23.243536    True         False
# 9               79.368728        28.056396    True         False
# 10             118.050489        21.818592   False         False
# 11              82.097289        20.016654   False         False
# 12             113.762837        24.352785    True         False
# 13              98.750718        29.163306    True         False
# 14             102.858340        21.265265    True          True
# 15             105.281429        25.727442   False         False
# 16              91.941432        20.274234    True         False
# 17             105.022274        25.954929    True          True
# 18              77.281271        20.019929   False         False
# 19              99.915502        29.387858    True          True
# 20              76.441582        21.569459    True         False
# 21             108.741984        27.012192    True          True
# 22              91.544058        19.769798   False          True
# 23             112.442135        20.410163   False          True
# 24              73.827348        19.177287   False          True
# 25             114.706719        28.017562    True         False
# 26             108.874195        27.952770   False          True
# 27              70.851862        25.748108    True         False
# 28              82.892434        19.413003   False          True
# 29              92.622093        22.495933    True          True
# 30             109.149680        22.391977   False         False
# 31             108.110426        22.107712   False          True
# 32              81.038628        21.003226   False          True
# 33             104.261869        28.867660    True          True
# 34             103.047844        20.164744   False         False
# 35              71.487724        27.393224   False         False
# 36              85.058653        22.916391   False          True
# 37              84.587573        20.774500    True         False
# 38              97.647067        19.322123   False          True
# 39             105.873264        23.549760   False          True
# 40              78.564796        20.038148   False          True
# 41              90.097586        27.784262    True         False
# 42              97.156485        27.778379   False         False
# 43              77.323898        18.977029    True          True
# 44              93.772323        29.104975   False          True
# 45             106.459767        19.424655   False          True
# 46              85.756662        28.667717    True          True
# 47             113.809330        22.702128   False          True
# 48              95.301248        26.886167   False          True
# 49             110.864541        19.887647    True          True
# 50             108.268616        29.707077   False         False
# 51             109.374555        29.683174   False         False
# 52              96.077099        25.729391   False          True
# 53              80.724916        26.112705   False         False
# 54              90.638083        21.245580    True          True
# 55             105.254809        19.281170    True         False
# 56              77.441689        22.454244    True          True
# 57              73.443560        20.440249   False         False
# 58             104.868144        26.995648   False         False
# 59              89.523570        24.992300   False         False
# 60              84.258505        20.339636    True          True
# 61             117.871227        20.543332   False         False
# 62             119.171623        19.866140    True         False
# 63              90.043833        24.210375   False          True
# 64              80.809523        22.640609   False          True
# 65              76.931920        24.203064    True          True
# 66              78.810602        25.745001   False         False
# 67              98.772287        26.634166    True          True
# 68             116.298804        20.699996   False         False
# 69              83.740048        21.152322   False         False
# 70              91.412460        29.431733    True         False
# 71             107.886554        21.133319    True          True
# 72             107.439512        28.884907    True         False
# 73              98.879736        18.992327    True          True
# 74              76.424310        28.003106   False          True
# 75             114.655585        20.789872    True         False
# 76              76.823096        29.016821    True          True
# 77             116.706270        21.676780   False          True
# 78             115.903839        22.538941    True          True
# 79             110.206245        28.794765    True         False
# 80             119.836373        20.473614   False         False
# 81              94.497205        23.332205   False          True
# 82              95.383294        24.923211    True          True
# 83              99.070082        19.907615    True         False
# 84              72.535990        21.935812   False         False
# 85              87.020927        23.220807    True         False
# 86              79.375129        25.170965    True         False
# 87              76.134916        23.056827    True          True
# 88              88.700003        29.871717    True         False
# 89             119.261552        22.449942   False          True
# 90             103.705913        21.373380    True         False
# 91             117.171393        26.960943    True         False
# 92              90.467335        28.878226    True          True
# 93             107.555324        21.816703   False         False
# 94              85.572685        24.836532    True          True
# 95             113.918522        21.325828    True         False
# 96              82.966369        28.927462   False          True
# 97             105.350208        23.555560    True          True
# 98              94.792695        27.540550    True          True
# 99              99.925881        27.532797    True         False
#
#     hyperlipidemia  ...  family_history_diabetes  physical_activity  \
# 0             True  ...                    False              False
# 1            False  ...                    False              False
# 2            False  ...                     True              False
# 3            False  ...                     True              False
# 4            False  ...                    False              False
# 5             True  ...                    False              False
# 6            False  ...                    False               True
# 7             True  ...                    False              False
# 8             True  ...                    False               True
# 9             True  ...                    False              False
# 10           False  ...                    False              False
# 11           False  ...                    False               True
# 12           False  ...                     True              False
# 13           False  ...                    False              False
# 14           False  ...                    False              False
# 15            True  ...                     True              False
# 16           False  ...                     True               True
# 17           False  ...                    False               True
# 18           False  ...                     True              False
# 19            True  ...                     True               True
# 20            True  ...                     True               True
# 21           False  ...                    False              False
# 22           False  ...                     True              False
# 23           False  ...                    False              False
# 24            True  ...                     True               True
# 25           False  ...                     True              False
# 26           False  ...                    False               True
# 27            True  ...                    False              False
# 28           False  ...                    False               True
# 29            True  ...                    False               True
# 30            True  ...                    False               True
# 31            True  ...                     True              False
# 32           False  ...                    False               True
# 33            True  ...                     True               True
# 34           False  ...                     True              False
# 35            True  ...                    False               True
# 36            True  ...                     True               True
# 37            True  ...                     True               True
# 38           False  ...                    False               True
# 39           False  ...                     True              False
# 40            True  ...                    False              False
# 41            True  ...                    False              False
# 42            True  ...                     True               True
# 43            True  ...                     True              False
# 44           False  ...                     True              False
# 45            True  ...                    False               True
# 46            True  ...                     True              False
# 47            True  ...                    False               True
# 48           False  ...                    False               True
# 49            True  ...                     True               True
# 50            True  ...                    False              False
# 51           False  ...                     True              False
# 52           False  ...                    False               True
# 53           False  ...                     True              False
# 54            True  ...                     True              False
# 55           False  ...                    False               True
# 56           False  ...                    False              False
# 57            True  ...                    False               True
# 58            True  ...                    False              False
# 59           False  ...                    False               True
# 60           False  ...                     True              False
# 61            True  ...                    False              False
# 62           False  ...                     True              False
# 63           False  ...                    False               True
# 64           False  ...                     True               True
# 65           False  ...                     True              False
# 66            True  ...                     True              False
# 67           False  ...                     True              False
# 68           False  ...                    False               True
# 69            True  ...                    False              False
# 70           False  ...                    False              False
# 71           False  ...                    False              False
# 72           False  ...                    False               True
# 73           False  ...                     True               True
# 74           False  ...                     True               True
# 75            True  ...                    False              False
# 76            True  ...                     True              False
# 77            True  ...                    False              False
# 78            True  ...                    False              False
# 79           False  ...                     True              False
# 80            True  ...                     True              False
# 81            True  ...                     True              False
# 82           False  ...                     True               True
# 83            True  ...                     True              False
# 84           False  ...                     True              False
# 85           False  ...                     True              False
# 86            True  ...                     True               True
# 87           False  ...                    False              False
# 88            True  ...                    False               True
# 89           False  ...                    False              False
# 90           False  ...                    False               True
# 91            True  ...                     True              False
# 92           False  ...                    False               True
# 93           False  ...                     True              False
# 94           False  ...                    False              False
# 95            True  ...                    False               True
# 96            True  ...                    False               True
# 97           False  ...                    False              False
# 98            True  ...                     True              False
# 99           False  ...                    False              False
#
#     diet_control  medication_adherence  health_insurance  blindness  \
# 0          False                  True              True      False
# 1           True                  True              True      False
# 2          False                 False             False      False
# 3           True                 False             False      False
# 4           True                  True              True      False
# 5           True                  True              True      False
# 6           True                 False             False      False
# 7          False                  True              True      False
# 8           True                  True             False      False
# 9          False                 False              True      False
# 10         False                  True              True      False
# 11          True                 False              True      False
# 12         False                  True             False      False
# 13         False                  True              True      False
# 14          True                  True             False      False
# 15         False                  True              True      False
# 16          True                 False             False      False
# 17         False                  True             False      False
# 18          True                  True              True      False
# 19         False                 False             False      False
# 20          True                 False              True      False
# 21         False                 False              True      False
# 22         False                  True             False      False
# 23          True                 False              True      False
# 24         False                 False              True      False
# 25         False                 False             False      False
# 26          True                  True              True      False
# 27         False                  True              True      False
# 28         False                 False              True      False
# 29          True                  True             False      False
# 30          True                 False              True      False
# 31          True                 False              True      False
# 32          True                 False              True      False
# 33          True                 False              True      False
# 34          True                 False             False      False
# 35          True                 False              True      False
# 36         False                 False             False      False
# 37         False                 False             False      False
# 38          True                 False             False      False
# 39          True                  True              True      False
# 40         False                 False              True      False
# 41         False                  True             False      False
# 42          True                 False             False      False
# 43         False                  True             False      False
# 44         False                 False             False      False
# 45         False                 False              True      False
# 46          True                 False             False      False
# 47         False                 False             False      False
# 48          True                  True              True      False
# 49         False                 False              True      False
# 50          True                  True             False      False
# 51         False                 False             False      False
# 52         False                  True              True      False
# 53         False                  True             False      False
# 54          True                 False             False      False
# 55         False                  True              True      False
# 56          True                 False             False      False
# 57         False                 False             False      False
# 58          True                  True             False      False
# 59          True                 False             False      False
# 60          True                 False              True      False
# 61          True                 False             False      False
# 62         False                 False              True      False
# 63         False                  True             False      False
# 64          True                  True              True      False
# 65         False                 False              True      False
# 66         False                  True              True      False
# 67          True                 False              True      False
# 68          True                 False              True      False
# 69          True                  True             False      False
# 70          True                 False             False      False
# 71         False                  True             False      False
# 72         False                  True              True      False
# 73          True                 False             False      False
# 74         False                 False             False      False
# 75          True                  True              True      False
# 76          True                 False             False      False
# 77         False                 False              True      False
# 78         False                 False             False      False
# 79          True                 False             False      False
# 80         False                  True             False      False
# 81          True                  True              True      False
# 82         False                  True             False      False
# 83         False                  True             False      False
# 84         False                 False              True      False
# 85          True                 False             False      False
# 86         False                 False             False      False
# 87         False                 False             False      False
# 88          True                  True              True      False
# 89          True                 False              True      False
# 90          True                  True              True      False
# 91          True                 False             False      False
# 92         False                  True              True      False
# 93          True                  True              True      False
# 94         False                  True              True      False
# 95          True                 False             False      False
# 96          True                  True              True      False
# 97         False                  True             False      False
# 98         False                  True             False      False
# 99         False                  True              True      False
#
#     retinopathy  neuropathy  nephropathy  foot_problems
# 0         False       False        False          False
# 1         False       False        False          False
# 2         False       False        False          False
# 3         False       False        False          False
# 4         False       False        False          False
# 5         False       False        False          False
# 6         False       False        False          False
# 7         False       False        False          False
# 8         False       False        False          False
# 9         False       False        False          False
# 10        False       False        False          False
# 11        False       False        False          False
# 12        False       False        False          False
# 13        False       False        False          False
# 14        False       False        False          False
# 15        False       False        False          False
# 16        False       False        False          False
# 17        False       False        False          False
# 18        False       False        False          False
# 19        False       False        False          False
# 20        False       False        False          False
# 21        False       False        False          False
# 22        False       False        False          False
# 23        False       False        False          False
# 24        False       False        False          False
# 25        False       False        False          False
# 26        False       False        False          False
# 27        False       False        False          False
# 28        False       False        False          False
# 29        False       False        False          False
# 30        False       False        False          False
# 31        False       False        False          False
# 32        False       False        False          False
# 33        False       False        False          False
# 34        False       False        False          False
# 35        False       False        False          False
# 36        False       False        False          False
# 37        False       False        False          False
# 38        False       False        False          False
# 39        False       False        False          False
# 40        False       False        False          False
# 41        False       False        False          False
# 42        False       False        False          False
# 43        False       False        False          False
# 44        False       False        False          False
# 45        False       False        False          False
# 46        False       False        False          False
# 47        False       False        False          False
# 48        False       False        False          False
# 49        False       False        False          False
# 50        False       False        False          False
# 51        False       False        False          False
# 52        False       False        False          False
# 53        False       False        False          False
# 54        False       False        False          False
# 55        False       False        False          False
# 56        False       False        False          False
# 57        False       False        False          False
# 58        False       False        False          False
# 59        False       False        False          False
# 60        False       False        False          False
# 61        False       False        False          False
# 62        False       False        False          False
# 63        False       False        False          False
# 64        False       False        False          False
# 65        False       False        False          False
# 66        False       False        False          False
# 67        False       False        False          False
# 68        False       False        False          False
# 69        False       False        False          False
# 70        False       False        False          False
# 71        False       False        False          False
# 72        False       False        False          False
# 73        False       False        False          False
# 74        False       False        False          False
# 75        False       False        False          False
# 76        False       False        False          False
# 77        False       False        False          False
# 78        False       False        False          False
# 79        False       False        False          False
# 80        False       False        False          False
# 81        False       False        False          False
# 82        False       False        False          False
# 83        False       False        False          False
# 84        False       False        False          False
# 85        False       False        False          False
# 86        False       False        False          False
# 87        False       False        False          False
# 88        False       False        False          False
# 89        False       False        False          False
# 90        False       False        False          False
# 91        False       False        False          False
# 92        False       False        False          False
# 93        False       False        False          False
# 94        False       False        False          False
# 95        False       False        False          False
# 96        False       False        False          False
# 97        False       False        False          False
# 98        False       False        False          False
# 99        False       False        False          False
#
# [100 rows x 21 columns]
