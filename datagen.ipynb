# %%
from langchain_openai import ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from typing import List
import pandas as pd
import numpy as np
import json

# %%
llm = ChatOpenAI(base_url="http://THOTH.local:1234/v1/", api_key="na", temperature=0.5)

# %%
class DatasetCol(BaseModel):
    name: str = Field(description="The name of the column.")
    type: str = Field(description="The type of the column. One of 'int', 'float', 'str', 'bool'.")
    description: str = Field(description="A description of the column.")
    dependent: bool = Field(description="Whether this column is dependent on other columns.")
    function: str = Field(description="A python function that generates the data for this column. The function takes parameters and returns the value for the column in that row. The function takes the row as a paramter with each column accessbile by name (Eg: row[\"name\"]). Independent variables cannot use any other variables in the dataset in their function including themselves.")

class DatasetGen(BaseModel):
    columns: List[DatasetCol] = Field(description="The columns of the dataset.")

# Set up a parser + inject instructions into the prompt template.
parser = JsonOutputParser(pydantic_object=DatasetGen)

# %%
def parser_to_prompt_schema(parser):
    schema = {k: v for k, v in parser._get_schema(parser.pydantic_object).items()}

    # Remove extraneous fields.
    reduced_schema = schema
    if "title" in reduced_schema:
        del reduced_schema["title"]
    if "type" in reduced_schema:
        del reduced_schema["type"]
    # Ensure json in context is well-formed with double quotes.
    schema_str = json.dumps(reduced_schema)

    return schema_str

# %%
def try_eval(fn_str, *params):
    try:
        return eval(fn_str)(*params)
    except:
        return None
def create_dataframe(data_template, n):
    columns = data_template['columns']
    data = {}
    independent_vars = {}
    # Generate values for independent variables
    for column in columns:
        if not column['dependent']:
            col_name = column['name']
            col_type = column['type']
            col_function = column['function']
            values = [try_eval(col_function, i) for i in range(n)]
            data[col_name] = values
    # Calculate values for dependent variables
    for column in columns:
        if column['dependent']:
            col_name = column['name']
            col_type = column['type']
            col_function = column['function']
            values = [eval(col_function)(pd.DataFrame(data).to_dict('records')[i]) for i in range(n)]
            data[col_name] = values

    df = pd.DataFrame(data)
    return df

# %%
template = '''
You are a helpful assistant that answers in JSON.
Generate an artificial medical research dataset containing 20-30 columns each.
The subject of this dataset is: {subject}.
For each column provide a python function using numpy to generate the data.

Here's the json schema you must adhere to:
<schema>
{schema}
</schema>
'''
prompt = PromptTemplate(
    template=template,
    input_variables=["subject"],
    partial_variables={"schema": parser_to_prompt_schema(parser)},
)

# %%
chain = prompt | llm | parser
data_template = chain.invoke({"subject": "blindness in diabetes"})

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
display(pd.DataFrame(data_template["columns"]))
# Out:
#                         name   type  \
# 0                 Patient_ID    int
# 1                        Age    int
# 2                     Gender    str
# 3              Diabetes_Type    str
# 4        Blood_Glucose_Level  float
# 5                      HbA1c  float
# 6    Blood_Pressure_Systolic    int
# 7   Blood_Pressure_Diastolic    int
# 8          Cholesterol_Level  float
# 9                     Smoker   bool
# 10          Blindness_Status    str
# 11        Retinopathy_Status    str
# 12              Age_at_Onset    int
# 13     Duration_of_Blindness    int
# 14            Treatment_Type    str
# 15        Treatment_Duration    int
# 16          Follow_up_Visits    int
# 17            Visual_Aid_Use    str
# 18      Eye_Examination_Date    str
# 19          Diabetes_Control    str
# 20             Complications    str
#
#                                                                   description  \
# 0                                         Unique identifier for each patient.
# 1                                            The age of the patient in years.
# 2                                    The gender of the patient (Male/Female).
# 3                           Type of diabetes the patient has (Type 1/Type 2).
# 4                            The blood glucose level of the patient in mg/dL.
# 5                                      The HbA1c level of the patient (in %).
# 6                         The systolic blood pressure of the patient in mmHg.
# 7                        The diastolic blood pressure of the patient in mmHg.
# 8                              The cholesterol level of the patient in mg/dL.
# 9                                     Whether the patient is a smoker or not.
# 10                              The blindness status of the patient (Yes/No).
# 11                            The retinopathy status of the patient (Yes/No).
# 12                         The age at which the patient's blindness occurred.
# 13                          The duration of the patient's blindness in years.
# 14                                   The treatment type given to the patient.
# 15                          The duration of the patient's treatment in years.
# 16                            The number of follow-up visits the patient had.
# 17  The type of visual aid used by the patient (Glasses/Contact Lenses/None).
# 18                            The date of the patient's last eye examination.
# 19                    The control of the patient's diabetes (Good/Fair/Poor).
# 20                     The complications experienced by the patient (Yes/No).
#
#     dependent  \
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
#
#                                                                                                                    function
# 0                                                                                        lambda row: int(row['Patient_ID'])
# 1                                                                                     lambda row: np.random.randint(18, 80)
# 2                                                                                  lambda row: np.random.choice(['M', 'F'])
# 3                                                                                lambda row: np.random.choice(['T1', 'T2'])
# 4                                                                                    lambda row: np.random.uniform(70, 300)
# 5                                                                                      lambda row: np.random.uniform(4, 10)
# 6                                                                                    lambda row: np.random.randint(80, 140)
# 7                                                                                     lambda row: np.random.randint(40, 90)
# 8                                                                                   lambda row: np.random.uniform(100, 300)
# 9                                                                               lambda row: np.random.choice([True, False])
# 10                                                          lambda row: 'Yes' if row['Blood_Glucose_Level'] > 400 else 'No'
# 11                                                          lambda row: 'Yes' if row['Blindness_Status'] == 'Yes' else 'No'
# 12                              lambda row: np.random.randint(row['Age'], 80) if row['Blindness_Status'] == 'Yes' else None
# 13                                       lambda row: np.random.randint(1, 20) if row['Blindness_Status'] == 'Yes' else None
# 14           lambda row: np.random.choice(['Insulin', 'Oral Medication', 'Both']) if row['Diabetes_Type'] == 'T1' else None
# 15                                          lambda row: np.random.randint(1, 10) if row['Treatment_Type'] != None else None
# 16                                        lambda row: np.random.randint(1, 5) if row['Blindness_Status'] == 'Yes' else None
# 17        lambda row: np.random.choice(['Glasses', 'Contact Lenses', 'None']) if row['Blindness_Status'] == 'Yes' else None
# 18   lambda row: np.random.choice(['2020-01-01', '2020-02-01', '2020-03-01']) if row['Blindness_Status'] == 'Yes' else None
# 19                                     lambda row: np.random.choice(['Good', 'Fair', 'Poor']) if row['HbA1c'] > 8 else None
# 20  lambda row: 'Yes' if len([x for x in [row['Blindness_Status'], row['Retinopathy_Status']] if x == 'Yes']) > 0 else 'No'

# %%
df = create_dataframe(data_template, 100)
display(df)
# Out:
#    Patient_ID  Age Gender Diabetes_Type  Blood_Glucose_Level     HbA1c  \
# 0        None   43      M            T2           216.194095  5.625996
# 1        None   65      M            T2            70.439844  6.087691
# 2        None   61      M            T1           148.560235  5.151963
# 3        None   71      F            T1           138.006827  8.613487
# 4        None   25      F            T2           272.665293  5.827095
# 5        None   25      F            T2           160.193434  5.424640
# 6        None   38      F            T1           125.579127  7.449622
# 7        None   46      M            T2           273.330431  6.039712
# 8        None   21      M            T1           146.633127  9.294553
# 9        None   74      F            T1           150.443148  9.838818
# 10       None   79      F            T2           155.263074  7.695496
# 11       None   60      F            T2           103.562953  5.540703
# 12       None   37      M            T2           156.668789  8.551442
# 13       None   73      M            T1           183.171057  6.963107
# 14       None   25      F            T1           111.879734  7.985495
# 15       None   49      F            T1           122.028235  4.382629
# 16       None   35      F            T1           258.893346  4.562764
# 17       None   73      F            T2           294.227999  7.503965
# 18       None   53      F            T2           194.576346  6.664397
# 19       None   79      M            T1           248.399391  5.120560
# 20       None   51      F            T2           185.050351  8.998126
# 21       None   39      F            T1           225.869267  5.472926
# 22       None   33      F            T2           131.055963  7.143069
# 23       None   71      M            T2           172.306513  9.933016
# 24       None   43      F            T2           109.722137  5.700241
# 25       None   53      F            T2           185.010458  8.031934
# 26       None   63      F            T1           295.994398  8.474358
# 27       None   29      F            T2           112.901366  4.857624
# 28       None   48      F            T1           173.808153  7.934873
# 29       None   47      M            T1           110.312373  5.732757
# 30       None   23      F            T1           199.625685  8.000158
# 31       None   53      F            T1           196.695820  5.630963
# 32       None   28      M            T2           160.208224  8.786239
# 33       None   56      F            T2            96.942895  5.949904
# 34       None   75      M            T2            97.480465  4.386939
# 35       None   33      M            T1           157.712153  4.832266
# 36       None   27      F            T2           291.954129  9.958402
# 37       None   26      M            T1           213.331206  8.237198
# 38       None   40      M            T1           136.414777  4.250327
# 39       None   58      F            T1           260.921221  9.642164
# 40       None   51      M            T1           280.036075  6.947568
# 41       None   29      M            T1           217.321534  8.967730
# 42       None   49      M            T2           266.919835  7.592109
# 43       None   71      M            T1           105.591660  6.507497
# 44       None   39      F            T1           221.364506  9.499575
# 45       None   50      M            T2           188.688461  5.727623
# 46       None   19      M            T1           199.495524  9.406251
# 47       None   23      M            T2           151.460926  8.766107
# 48       None   61      F            T2           299.253123  9.431747
# 49       None   28      F            T1            80.378769  6.680230
# 50       None   49      M            T2           104.368853  6.033787
# 51       None   52      M            T2           175.409008  5.979839
# 52       None   23      F            T2           237.360770  9.725261
# 53       None   66      F            T1           104.656370  5.426031
# 54       None   23      M            T1            80.441134  8.258177
# 55       None   78      M            T1           106.437631  9.536155
# 56       None   33      F            T2           257.042153  5.830750
# 57       None   19      F            T2           143.703049  6.447617
# 58       None   61      F            T1           184.299853  6.856773
# 59       None   54      M            T2           143.547751  8.141932
# 60       None   42      M            T2            94.029069  5.059278
# 61       None   65      F            T1           138.485186  9.508294
# 62       None   47      M            T1           260.291613  9.521948
# 63       None   31      F            T1           126.055476  9.760202
# 64       None   45      F            T1           251.279868  4.875911
# 65       None   59      F            T2           142.307279  7.427304
# 66       None   48      F            T1           289.428051  4.924196
# 67       None   46      F            T1           199.567611  6.475202
# 68       None   47      F            T2           263.333042  6.224595
# 69       None   35      F            T2           190.992077  5.819082
# 70       None   64      M            T2           113.027906  5.058857
# 71       None   32      M            T2           236.784228  9.669541
# 72       None   29      M            T1           195.632080  9.630232
# 73       None   60      F            T1            81.372357  7.725335
# 74       None   30      M            T1           292.909932  5.022310
# 75       None   23      M            T1           130.820622  7.872455
# 76       None   26      M            T2           269.167474  7.569021
# 77       None   53      F            T1           172.881404  6.426074
# 78       None   18      F            T1           246.597564  9.983606
# 79       None   75      M            T2           194.104722  7.517253
# 80       None   73      F            T1           154.511193  9.011624
# 81       None   65      F            T2            72.011280  9.590766
# 82       None   65      F            T1           171.939165  4.957331
# 83       None   63      F            T1           243.906825  5.760277
# 84       None   56      M            T1           109.343829  4.215539
# 85       None   70      F            T1           157.414490  6.025379
# 86       None   27      F            T2           163.910683  5.660145
# 87       None   70      M            T2           167.986836  9.227480
# 88       None   70      F            T2           110.648441  9.504810
# 89       None   37      M            T1           196.819352  5.659044
# 90       None   31      F            T2           113.542032  6.621214
# 91       None   23      F            T2           288.604787  7.720126
# 92       None   22      F            T2           227.636034  5.027973
# 93       None   61      F            T2            74.590195  4.634208
# 94       None   79      F            T1           221.336404  8.491253
# 95       None   75      F            T1           100.822681  4.035172
# 96       None   18      F            T1           269.549829  6.201409
# 97       None   69      F            T2           171.930827  9.879372
# 98       None   58      F            T2           156.854013  7.699605
# 99       None   72      F            T2           231.723206  7.628596
#
#     Blood_Pressure_Systolic  Blood_Pressure_Diastolic  Cholesterol_Level  \
# 0                       134                        85         202.955529
# 1                       125                        74         131.954730
# 2                       126                        61         153.481332
# 3                       115                        71         247.591967
# 4                       115                        53         126.982635
# 5                        80                        50         282.857252
# 6                        98                        52         228.385735
# 7                       110                        72         263.900710
# 8                       127                        69         125.379490
# 9                       132                        47         283.304995
# 10                      117                        65         268.131948
# 11                       83                        71         114.638025
# 12                       94                        43         123.439328
# 13                       80                        73         223.137147
# 14                       98                        53         255.152064
# 15                      133                        79         269.153925
# 16                      103                        46         289.705988
# 17                       92                        65         131.559519
# 18                      127                        46         142.236726
# 19                       94                        84         244.237286
# 20                      130                        50         232.388610
# 21                       90                        77         171.912539
# 22                      100                        65         281.724118
# 23                      128                        52         126.048927
# 24                       95                        71         185.226698
# 25                      130                        89         253.960363
# 26                       91                        53         249.955614
# 27                       81                        83         119.171437
# 28                      136                        41         236.101663
# 29                      112                        81         204.157729
# 30                       97                        58         215.581442
# 31                      134                        70         244.950654
# 32                      103                        48         138.224637
# 33                      120                        42         161.405719
# 34                      124                        48         235.939920
# 35                      132                        88         224.706488
# 36                       84                        73         283.291052
# 37                       80                        43         190.767323
# 38                      104                        60         208.401477
# 39                       89                        64         132.890785
# 40                      100                        61         176.920001
# 41                       86                        75         194.705266
# 42                      137                        78         181.045342
# 43                      104                        64         110.340686
# 44                       97                        62         162.421663
# 45                      104                        74         250.764160
# 46                      139                        71         218.773341
# 47                      117                        88         170.023653
# 48                      111                        60         247.410122
# 49                       85                        67         177.273666
# 50                      105                        58         155.649788
# 51                       95                        67         103.973906
# 52                      134                        53         227.685755
# 53                       81                        76         205.616944
# 54                       84                        81         255.689426
# 55                      125                        51         236.687848
# 56                      137                        66         173.771668
# 57                      125                        71         112.174049
# 58                      113                        66         179.536848
# 59                      120                        43         272.150921
# 60                      132                        57         215.878917
# 61                       97                        73         158.055836
# 62                      133                        53         213.825969
# 63                      129                        64         116.096082
# 64                      112                        67         182.536082
# 65                      107                        46         197.182253
# 66                      115                        57         224.610677
# 67                       93                        83         292.945009
# 68                       98                        63         184.564156
# 69                      139                        77         134.279729
# 70                      121                        76         191.302997
# 71                       82                        73         157.705975
# 72                       85                        88         176.226095
# 73                      135                        53         205.571840
# 74                      101                        44         150.434880
# 75                      105                        58         127.593080
# 76                       91                        87         280.856156
# 77                      127                        83         231.654443
# 78                       85                        76         290.718848
# 79                      123                        45         130.057597
# 80                      126                        47         272.425051
# 81                      107                        75         277.947333
# 82                      109                        46         284.760580
# 83                      110                        55         205.467198
# 84                      133                        42         121.268086
# 85                      101                        84         235.296261
# 86                      133                        80         179.568696
# 87                      133                        78         135.925854
# 88                       91                        43         199.027562
# 89                       82                        71         177.909008
# 90                       85                        59         157.443500
# 91                      101                        59         202.939875
# 92                      133                        51         268.760354
# 93                       97                        74         153.618379
# 94                       93                        66         283.833424
# 95                       89                        43         205.661742
# 96                       80                        71         289.384665
# 97                      101                        43         143.913434
# 98                      106                        63         142.310400
# 99                      100                        72         136.641890
#
#     Smoker  ... Retinopathy_Status Age_at_Onset Duration_of_Blindness  \
# 0     True  ...                 No         None                  None
# 1    False  ...                 No         None                  None
# 2     True  ...                 No         None                  None
# 3     True  ...                 No         None                  None
# 4    False  ...                 No         None                  None
# 5     True  ...                 No         None                  None
# 6     True  ...                 No         None                  None
# 7     True  ...                 No         None                  None
# 8    False  ...                 No         None                  None
# 9    False  ...                 No         None                  None
# 10   False  ...                 No         None                  None
# 11    True  ...                 No         None                  None
# 12   False  ...                 No         None                  None
# 13    True  ...                 No         None                  None
# 14    True  ...                 No         None                  None
# 15   False  ...                 No         None                  None
# 16    True  ...                 No         None                  None
# 17   False  ...                 No         None                  None
# 18    True  ...                 No         None                  None
# 19    True  ...                 No         None                  None
# 20    True  ...                 No         None                  None
# 21    True  ...                 No         None                  None
# 22   False  ...                 No         None                  None
# 23   False  ...                 No         None                  None
# 24   False  ...                 No         None                  None
# 25   False  ...                 No         None                  None
# 26   False  ...                 No         None                  None
# 27   False  ...                 No         None                  None
# 28    True  ...                 No         None                  None
# 29   False  ...                 No         None                  None
# 30    True  ...                 No         None                  None
# 31    True  ...                 No         None                  None
# 32    True  ...                 No         None                  None
# 33   False  ...                 No         None                  None
# 34    True  ...                 No         None                  None
# 35    True  ...                 No         None                  None
# 36    True  ...                 No         None                  None
# 37    True  ...                 No         None                  None
# 38   False  ...                 No         None                  None
# 39    True  ...                 No         None                  None
# 40    True  ...                 No         None                  None
# 41    True  ...                 No         None                  None
# 42    True  ...                 No         None                  None
# 43    True  ...                 No         None                  None
# 44    True  ...                 No         None                  None
# 45   False  ...                 No         None                  None
# 46   False  ...                 No         None                  None
# 47    True  ...                 No         None                  None
# 48   False  ...                 No         None                  None
# 49    True  ...                 No         None                  None
# 50   False  ...                 No         None                  None
# 51   False  ...                 No         None                  None
# 52    True  ...                 No         None                  None
# 53    True  ...                 No         None                  None
# 54    True  ...                 No         None                  None
# 55    True  ...                 No         None                  None
# 56    True  ...                 No         None                  None
# 57    True  ...                 No         None                  None
# 58    True  ...                 No         None                  None
# 59    True  ...                 No         None                  None
# 60    True  ...                 No         None                  None
# 61    True  ...                 No         None                  None
# 62   False  ...                 No         None                  None
# 63    True  ...                 No         None                  None
# 64   False  ...                 No         None                  None
# 65   False  ...                 No         None                  None
# 66   False  ...                 No         None                  None
# 67    True  ...                 No         None                  None
# 68   False  ...                 No         None                  None
# 69    True  ...                 No         None                  None
# 70   False  ...                 No         None                  None
# 71    True  ...                 No         None                  None
# 72    True  ...                 No         None                  None
# 73   False  ...                 No         None                  None
# 74   False  ...                 No         None                  None
# 75    True  ...                 No         None                  None
# 76   False  ...                 No         None                  None
# 77   False  ...                 No         None                  None
# 78   False  ...                 No         None                  None
# 79    True  ...                 No         None                  None
# 80    True  ...                 No         None                  None
# 81   False  ...                 No         None                  None
# 82    True  ...                 No         None                  None
# 83    True  ...                 No         None                  None
# 84   False  ...                 No         None                  None
# 85    True  ...                 No         None                  None
# 86   False  ...                 No         None                  None
# 87    True  ...                 No         None                  None
# 88   False  ...                 No         None                  None
# 89    True  ...                 No         None                  None
# 90    True  ...                 No         None                  None
# 91   False  ...                 No         None                  None
# 92   False  ...                 No         None                  None
# 93    True  ...                 No         None                  None
# 94   False  ...                 No         None                  None
# 95   False  ...                 No         None                  None
# 96    True  ...                 No         None                  None
# 97   False  ...                 No         None                  None
# 98   False  ...                 No         None                  None
# 99    True  ...                 No         None                  None
#
#      Treatment_Type Treatment_Duration  Follow_up_Visits Visual_Aid_Use  \
# 0              None                NaN              None           None
# 1              None                NaN              None           None
# 2           Insulin                5.0              None           None
# 3           Insulin                3.0              None           None
# 4              None                NaN              None           None
# 5              None                NaN              None           None
# 6           Insulin                8.0              None           None
# 7              None                NaN              None           None
# 8           Insulin                3.0              None           None
# 9   Oral Medication                4.0              None           None
# 10             None                NaN              None           None
# 11             None                NaN              None           None
# 12             None                NaN              None           None
# 13             Both                7.0              None           None
# 14          Insulin                5.0              None           None
# 15  Oral Medication                7.0              None           None
# 16  Oral Medication                8.0              None           None
# 17             None                NaN              None           None
# 18             None                NaN              None           None
# 19  Oral Medication                9.0              None           None
# 20             None                NaN              None           None
# 21          Insulin                2.0              None           None
# 22             None                NaN              None           None
# 23             None                NaN              None           None
# 24             None                NaN              None           None
# 25             None                NaN              None           None
# 26          Insulin                1.0              None           None
# 27             None                NaN              None           None
# 28  Oral Medication                6.0              None           None
# 29          Insulin                3.0              None           None
# 30             Both                9.0              None           None
# 31             Both                4.0              None           None
# 32             None                NaN              None           None
# 33             None                NaN              None           None
# 34             None                NaN              None           None
# 35          Insulin                1.0              None           None
# 36             None                NaN              None           None
# 37             Both                9.0              None           None
# 38             Both                3.0              None           None
# 39             Both                1.0              None           None
# 40  Oral Medication                2.0              None           None
# 41             Both                1.0              None           None
# 42             None                NaN              None           None
# 43          Insulin                6.0              None           None
# 44          Insulin                2.0              None           None
# 45             None                NaN              None           None
# 46          Insulin                1.0              None           None
# 47             None                NaN              None           None
# 48             None                NaN              None           None
# 49             Both                1.0              None           None
# 50             None                NaN              None           None
# 51             None                NaN              None           None
# 52             None                NaN              None           None
# 53             Both                8.0              None           None
# 54             Both                1.0              None           None
# 55          Insulin                8.0              None           None
# 56             None                NaN              None           None
# 57             None                NaN              None           None
# 58             Both                3.0              None           None
# 59             None                NaN              None           None
# 60             None                NaN              None           None
# 61             Both                6.0              None           None
# 62             Both                5.0              None           None
# 63             Both                3.0              None           None
# 64  Oral Medication                7.0              None           None
# 65             None                NaN              None           None
# 66          Insulin                5.0              None           None
# 67             Both                4.0              None           None
# 68             None                NaN              None           None
# 69             None                NaN              None           None
# 70             None                NaN              None           None
# 71             None                NaN              None           None
# 72             Both                7.0              None           None
# 73             Both                3.0              None           None
# 74  Oral Medication                9.0              None           None
# 75  Oral Medication                5.0              None           None
# 76             None                NaN              None           None
# 77  Oral Medication                1.0              None           None
# 78             Both                3.0              None           None
# 79             None                NaN              None           None
# 80          Insulin                1.0              None           None
# 81             None                NaN              None           None
# 82  Oral Medication                5.0              None           None
# 83             Both                6.0              None           None
# 84             Both                4.0              None           None
# 85          Insulin                6.0              None           None
# 86             None                NaN              None           None
# 87             None                NaN              None           None
# 88             None                NaN              None           None
# 89  Oral Medication                4.0              None           None
# 90             None                NaN              None           None
# 91             None                NaN              None           None
# 92             None                NaN              None           None
# 93             None                NaN              None           None
# 94          Insulin                4.0              None           None
# 95  Oral Medication                6.0              None           None
# 96  Oral Medication                9.0              None           None
# 97             None                NaN              None           None
# 98             None                NaN              None           None
# 99             None                NaN              None           None
#
#    Eye_Examination_Date Diabetes_Control Complications
# 0                  None             None            No
# 1                  None             None            No
# 2                  None             None            No
# 3                  None             Good            No
# 4                  None             None            No
# 5                  None             None            No
# 6                  None             None            No
# 7                  None             None            No
# 8                  None             Good            No
# 9                  None             Fair            No
# 10                 None             None            No
# 11                 None             None            No
# 12                 None             Poor            No
# 13                 None             None            No
# 14                 None             None            No
# 15                 None             None            No
# 16                 None             None            No
# 17                 None             None            No
# 18                 None             None            No
# 19                 None             None            No
# 20                 None             Poor            No
# 21                 None             None            No
# 22                 None             None            No
# 23                 None             Good            No
# 24                 None             None            No
# 25                 None             Poor            No
# 26                 None             Poor            No
# 27                 None             None            No
# 28                 None             None            No
# 29                 None             None            No
# 30                 None             Poor            No
# 31                 None             None            No
# 32                 None             Fair            No
# 33                 None             None            No
# 34                 None             None            No
# 35                 None             None            No
# 36                 None             Fair            No
# 37                 None             Good            No
# 38                 None             None            No
# 39                 None             Poor            No
# 40                 None             None            No
# 41                 None             Fair            No
# 42                 None             None            No
# 43                 None             None            No
# 44                 None             Fair            No
# 45                 None             None            No
# 46                 None             Poor            No
# 47                 None             Poor            No
# 48                 None             Poor            No
# 49                 None             None            No
# 50                 None             None            No
# 51                 None             None            No
# 52                 None             Fair            No
# 53                 None             None            No
# 54                 None             Good            No
# 55                 None             Good            No
# 56                 None             None            No
# 57                 None             None            No
# 58                 None             None            No
# 59                 None             Poor            No
# 60                 None             None            No
# 61                 None             Good            No
# 62                 None             Good            No
# 63                 None             Poor            No
# 64                 None             None            No
# 65                 None             None            No
# 66                 None             None            No
# 67                 None             None            No
# 68                 None             None            No
# 69                 None             None            No
# 70                 None             None            No
# 71                 None             Poor            No
# 72                 None             Good            No
# 73                 None             None            No
# 74                 None             None            No
# 75                 None             None            No
# 76                 None             None            No
# 77                 None             None            No
# 78                 None             Fair            No
# 79                 None             None            No
# 80                 None             Poor            No
# 81                 None             Fair            No
# 82                 None             None            No
# 83                 None             None            No
# 84                 None             None            No
# 85                 None             None            No
# 86                 None             None            No
# 87                 None             Fair            No
# 88                 None             Poor            No
# 89                 None             None            No
# 90                 None             None            No
# 91                 None             None            No
# 92                 None             None            No
# 93                 None             None            No
# 94                 None             Good            No
# 95                 None             None            No
# 96                 None             None            No
# 97                 None             Good            No
# 98                 None             None            No
# 99                 None             None            No
#
# [100 rows x 21 columns]
